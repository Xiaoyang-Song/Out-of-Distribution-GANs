# %%
# %load_ext autoreload
# %autoreload 2
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = "Github"
GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
print(os.listdir(GOOGLE_DRIVE_PATH))
# Out:
# ['Colab_Sync.ipynb']

# %%
import sys
sys.path.append(GOOGLE_DRIVE_PATH)
import time, os
os.environ["TZ"] = "US/Eastern"
time.tzset()

# %% [markdown]
# # Github Control Setup

# %% [markdown]
# ## Redirect to root folder (Necessary when starting Colab runtime)

# %%
# %cd /content/drive/MyDrive/Github/
# Out:
# /content/drive/MyDrive/Github

# %% [markdown]
# ## Only run once upon initializing Colab runtime

# %% [markdown]
# ### Xiaoyang Song

# %%
username = "Xiaoyang-Song"
repository = "Out-of-Distribution-GANs"
git_token = "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"

# %% [markdown]
# ### Others

# %%
# username = "Xiaoyang-Song"
# repository = "NYC-Restaurant-Inspection-Database"
# git_token = "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"

# %% [markdown]
# ### Connect to Github

# %%
# !git clone https://{git_token}@github.com/{username}/{repository}
# Out:
# Cloning into 'Out-of-Distribution-GANs'...
# remote: Enumerating objects: 895, done.
# remote: Counting objects: 100% (156/156), done.
# remote: Compressing objects: 100% (110/110), done.
# remote: Total 895 (delta 94), reused 105 (delta 46), pack-reused 739
# Receiving objects: 100% (895/895), 57.77 MiB | 14.93 MiB/s, done.
# Resolving deltas: 100% (465/465), done.
# Checking out files: 100% (125/125), done.

# %% [markdown]
# ## Run to direct to Git Repo

# %%
# %cd {repository}
# Out:
# /content/drive/MyDrive/Github/Out-of-Distribution-GANs

# %%
# %ls -a
# Out:
# checkpoint/     .git/         models/       trainers/       wass_loss.py
# config.py       .gitignore    Notebooks/    utils.py
# dataset.py      metrics.py    README.md     Visualization/
# GDLossTracker/  mnist_cnn.pt  sobol_seq.py  wasserstein.py

# %%
# !git config --global user.email "sxy0425@outlook.com"

# %% [markdown]
# ## Commit Message

# %%
commit_message = "Colab Sync basic setup"

# %% [markdown]
# ## Run to commit and push

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git add .

# %%
# !git commit -m "{commit_message}"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git push
# Out:
# Everything up-to-date
